# %%
import pandas as pd
import numpy as np
import sklearn
import spacy

# %%
import numpy as np

# %%
df=pd.read_csv("./Fake_Real_Data (1).csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9900 entries, 0 to 9899
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Text    9900 non-null   object
#  1   label   9900 non-null   object
# dtypes: object(2)
# memory usage: 154.8+ KB

# %%
nlp=spacy.load("en_core_web_sm")

# %%
df=nlp("adsfbkvb fal hals fdslhf bffa fblkdfbf la")

# %%
for x in df.sents:
    print(x)
# Out:
# adsfbkvb fal hals fdslhf bffa fblkdfbf la

# %%
list(df.sents)
# Out:
# [adsfbkvb fal hals fdslhf bffa fblkdfbf la]

# %%
print(df.)
# Out:
# <bound method Doc.retokenize of adsfbkvb fal hals fdslhf bffa fblkdfbf la>

# %%
# Out:
# <bound method Doc.retokenize of adsfbkvb fal hals fdslhf bffa fblkdfbf la>

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("./bengaluru_house_prices.csv")

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df1=df.drop(columns=["area_type","availability","society","balcony"],axis=1)

# %%
df1
# Out:
#                        location       size total_sqft  bath   price
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0   51.00
# ...                         ...        ...        ...   ...     ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00
# 13316             Richards Town      4 BHK       3600   5.0  400.00
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00
# 13319              Doddathoguru      1 BHK        550   1.0   17.00
#
# [13320 rows x 5 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13319 non-null  object
#  1   size        13304 non-null  object
#  2   total_sqft  13320 non-null  object
#  3   bath        13247 non-null  float64
#  4   price       13320 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 520.4+ KB

# %%
df1.isna().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
df2=df1.dropna()

# %%
df2["size"]=df2["size"].apply(lambda x : x[0])
# Out:
# C:\Users\pruth\AppData\Local\Temp\ipykernel_20000\1399810983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["size"]=df2["size"].apply(lambda x : x[0])

# %%
df2["size"].isna().sum()
# Out:
# np.int64(0)

# %%
df2["size"]=df2["size"].astype(int)
# Out:
# C:\Users\pruth\AppData\Local\Temp\ipykernel_20000\1669050638.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["size"]=df2["size"].astype(int)

# %%
if df2.size > df2.bath+1 :
    pass
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20000\2163322456.py in ?()
# ----> 1 if df2.size > df2.bath+1 :
#       2     pass
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df2
# Out:
#                        location  size total_sqft  bath   price
# 0      Electronic City Phase II     2       1056   2.0   39.07
# 1              Chikka Tirupathi     4       2600   5.0  120.00
# 2                   Uttarahalli     3       1440   2.0   62.00
# 3            Lingadheeranahalli     3       1521   3.0   95.00
# 4                      Kothanur     2       1200   2.0   51.00
# ...                         ...   ...        ...   ...     ...
# 13315                Whitefield     5       3453   4.0  231.00
# 13316             Richards Town     4       3600   5.0  400.00
# 13317     Raja Rajeshwari Nagar     2       1141   2.0   60.00
# 13318           Padmanabhanagar     4       4689   4.0  488.00
# 13319              Doddathoguru     1        550   1.0   17.00
#
# [13246 rows x 5 columns]

# %%
df3=df2[df2["size"]>=df2.bath]

# %%
df3
# Out:
#                        location  size total_sqft  bath   price
# 0      Electronic City Phase II     2       1056   2.0   39.07
# 2                   Uttarahalli     3       1440   2.0   62.00
# 3            Lingadheeranahalli     3       1521   3.0   95.00
# 4                      Kothanur     2       1200   2.0   51.00
# 5                    Whitefield     2       1170   2.0   38.00
# ...                         ...   ...        ...   ...     ...
# 13314         Green Glen Layout     3       1715   3.0  112.00
# 13315                Whitefield     5       3453   4.0  231.00
# 13317     Raja Rajeshwari Nagar     2       1141   2.0   60.00
# 13318           Padmanabhanagar     4       4689   4.0  488.00
# 13319              Doddathoguru     1        550   1.0   17.00
#
# [12320 rows x 5 columns]

# %%
df3.groupby("location")["location"].count()
# Out:
# location
#  Anekal                 1
#  Banaswadi              1
#  Basavangudi            1
#  Bhoganhalli            1
#  Devarabeesana Halli    6
#                        ..
# t.c palya               1
# tc.palya                4
# vinayakanagar           1
# white field,kadugodi    1
# whitefiled              1
# Name: location, Length: 1251, dtype: int64

# %%
df3[df3.location.value_counts()>10
# Out:
# C:\Users\pruth\AppData\Local\Temp\ipykernel_20000\1787763920.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3[df3.location.value_counts()>10]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 df3[df3.location.value_counts()>10]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# ...

# %%
df3[df3.location.value_counts()>10]
# Out:
# C:\Users\pruth\AppData\Local\Temp\ipykernel_20000\1787763920.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df3[df3.location.value_counts()>10]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 df3[df3.location.value_counts()>10]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# ...

# %%
df3.where()
